# %%
# What do we do about the SIC codes?
# Search for "imbalanced class" for imbalanced class setup

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import gc

# %%
data = pd.read_csv('stock_price_data.csv')
first_day = pd.to_datetime('2024-1-3')
last_day = pd.to_datetime('2024-2-13')
num_of_ts = 29  # Number of timestamps; later remove one because the last timestamp is for testing
seq_length = 20 # Length of time-series
num_of_classes = 10
# 5 classes for imbalanced class setup
# num_of_classes = 5 # Top 2 and bottom 2 are two and bottom 2%; middle class is remaining 96%
seed = 120 # To set global seed later for reproducible results

# Some stocks are double listed, so company name cannot differentiate among them
# Tickers seem to be enough; number of unique tickers = 6345

# number of unique company names = 6293

# data['id'] = data['GVKEY'] + 0.1*data['iid']
# number of unique data['id'] = 6344; WHY IS IT LESS??

tickers = data['tic'].unique()
print(f'There are {len(tickers)} unique tickers in raw data')

# For grouping later
data['datadate'] = pd.to_datetime(data['datadate'], format='%m/%d/%Y')

# Remove entries where the dates are in the future
data = data[data['datadate'] < last_day]

print(f'Raw data has shape {data.shape}')
# Out:
# There are 6345 unique tickers in raw data
# Raw data has shape (181872, 13)

# %%
cols = list(data.columns)
factors = list(set(data.columns).difference({'GVKEY', 'iid', 'datadate', 'tic', 'conm', 'sic'}))
print(f'all columns {cols}')
print(f'all factors {factors}')

print(f'columns with missing data are {data.columns[data.isnull().sum() != 0]}')
# Out:
# all columns ['GVKEY', 'iid', 'datadate', 'tic', 'conm', 'cshoc', 'cshtrd', 'eps', 'prccd', 'prchd', 'prcld', 'prcod', 'sic']
# all factors ['eps', 'prcld', 'prchd', 'cshtrd', 'prccd', 'cshoc', 'prcod']
# columns with missing data are Index(['cshoc', 'cshtrd', 'eps', 'prccd', 'prchd', 'prcld', 'prcod'], dtype='object')

# %%
def remove_tic(data, tickers):
    # Remove entries without key factors such as trading volume, open/close prices
    to_remove = []
    for f in factors:
        factor_missing = data[data[f].isna()] # rows with factor f missing
        tic_missing = list(factor_missing['tic'].unique()) # find all tickers with missing f
        to_remove = to_remove + tic_missing # add tickers to the list of tickers that will be removed
    print(f'There are {len(set(to_remove))} tickers to remove due to missing factors')
    data = data[~data['tic'].isin(to_remove)]
    
    # Remove entries where there are not enough number of time stamps
    databytic_count = data.groupby('tic').count()
    incomplete_tics = databytic_count.loc[databytic_count['datadate']<num_of_ts].index.tolist()
    data = data[~data['tic'].isin(incomplete_tics)]
    tickers = data['tic'].unique()
    print(f'There are {len(incomplete_tics)} unique tickers to remove due to insufficient timestamps')
    print('There are ' + str(len(tickers)) + ' tickers')

    print(f'Confirm there are no more columns with missing data {data.columns[data.isnull().sum() != 0]}')
    
    # Sort data by tickers and date
    data = data.sort_values(by=['tic','datadate'])
    data = data.reset_index(drop=True)
    
    # Miscellaneous
    tic_comp_dict = dict(zip(data.tic, data.conm))
    data.insert(3, 'tic_num', pd.factorize(data['tic'])[0])
    
    return data, tickers, tic_comp_dict

data, tickers, tic_comp_dict = remove_tic(data, tickers)
# Out:
# There are 1822 tickers to remove due to missing factors
# There are 31 unique tickers to remove due to insufficient timestamps
# There are 4492 tickers
# Confirm there are no more columns with missing data Index([], dtype='object')

# %%
# Compute a new column: percentage daily return (ret_d)
def compute_ret(data):
    # Add additional column 'ret_d'
    data['ret_d']=data.groupby('tic')['prccd'].pct_change()
    # Shift all numbers up by one day. e.g. 2024-2-2's ret_d is the percentage return of 2024-2-3's daily return
    # It is easier for training this way since we want to predict next day's return
    data['ret_d'] = data.groupby('tic')['ret_d'].shift(-1)

    # Currently the last day has no ret_d since it's the test date. Fill it with 0 (optional)
    data = data.fillna(0)
    data = data.reset_index(drop=True)
    
    return data

data = compute_ret(data)

print(f'Final data has shape {data.shape}')

# Make sure every ticker has exactly num_of_ts timestamps
assert len(tickers) * num_of_ts == data.shape[0]
# Out:
# Final data has shape (130268, 15)

# %%
# Give each ticker a numerical label for easier reference, stored in a dictionary
all_tickers = list(data['tic'].unique())
all_tickers.sort()
def num_to_tic(all_tickers):
    l = len(all_tickers)
    num_to_tic_dict = {}
    for i in range(l):
        num_to_tic_dict[i] = all_tickers[i]
    return num_to_tic_dict

num_to_tic_dict = num_to_tic(all_tickers)

# %%
# Optionally look at the first two companies
data.head(2*num_of_ts)
# Out:
#      GVKEY  iid   datadate  tic_num tic                      conm  \
# 0   126554    1 2024-01-02        0   A  AGILENT TECHNOLOGIES INC
# 1   126554    1 2024-01-03        0   A  AGILENT TECHNOLOGIES INC
# 2   126554    1 2024-01-04        0   A  AGILENT TECHNOLOGIES INC
# 3   126554    1 2024-01-05        0   A  AGILENT TECHNOLOGIES INC
# 4   126554    1 2024-01-08        0   A  AGILENT TECHNOLOGIES INC
# 5   126554    1 2024-01-09        0   A  AGILENT TECHNOLOGIES INC
# 6   126554    1 2024-01-10        0   A  AGILENT TECHNOLOGIES INC
# 7   126554    1 2024-01-11        0   A  AGILENT TECHNOLOGIES INC
# 8   126554    1 2024-01-12        0   A  AGILENT TECHNOLOGIES INC
# 9   126554    1 2024-01-16        0   A  AGILENT TECHNOLOGIES INC
# 10  126554    1 2024-01-17        0   A  AGILENT TECHNOLOGIES INC
# 11  126554    1 2024-01-18        0   A  AGILENT TECHNOLOGIES INC
# 12  126554    1 2024-01-19        0   A  AGILENT TECHNOLOGIES INC
# 13  126554    1 2024-01-22        0   A  AGILENT TECHNOLOGIES INC
# 14  126554    1 2024-01-23        0   A  AGILENT TECHNOLOGIES INC
# 15  126554    1 2024-01-24        0   A  AGILENT TECHNOLOGIES INC
# 16  126554    1 2024-01-25        0   A  AGILENT TECHNOLOGIES INC
# 17  126554    1 2024-01-26        0   A  AGILENT TECHNOLOGIES INC
# 18  126554    1 2024-01-29        0   A  AGILENT TECHNOLOGIES INC
# 19  126554    1 2024-01-30        0   A  AGILENT TECHNOLOGIES INC
# 20  126554    1 2024-01-31        0   A  AGILENT TECHNOLOGIES INC
# 21  126554    1 2024-02-01        0   A  AGILENT TECHNOLOGIES INC
# 22  126554    1 2024-02-02        0   A  AGILENT TECHNOLOGIES INC
# 23  126554    1 2024-02-05        0   A  AGILENT TECHNOLOGIES INC
# 24  126554    1 2024-02-06        0   A  AGILENT TECHNOLOGIES INC
# 25  126554    1 2024-02-07        0   A  AGILENT TECHNOLOGIES INC
# 26  126554    1 2024-02-08        0   A  AGILENT TECHNOLOGIES INC
# 27  126554    1 2024-02-09        0   A  AGILENT TECHNOLOGIES INC
# 28  126554    1 2024-02-12        0   A  AGILENT TECHNOLOGIES INC
# 29   27638    1 2024-01-02        1  AA                ALCOA CORP
# 30   27638    1 2024-01-03        1  AA                ALCOA CORP
# 31   27638    1 2024-01-04        1  AA                ALCOA CORP
# 32   27638    1 2024-01-05        1  AA                ALCOA CORP
# 33   27638    1 2024-01-08        1  AA                ALCOA CORP
# 34   27638    1 2024-01-09        1  AA                ALCOA CORP
# 35   27638    1 2024-01-10        1  AA                ALCOA CORP
# 36   27638    1 2024-01-11        1  AA                ALCOA CORP
# 37   27638    1 2024-01-12        1  AA                ALCOA CORP
# 38   27638    1 2024-01-16        1  AA                ALCOA CORP
# 39   27638    1 2024-01-17        1  AA                ALCOA CORP
# 40   27638    1 2024-01-18        1  AA                ALCOA CORP
# 41   27638    1 2024-01-19        1  AA                ALCOA CORP
# 42   27638    1 2024-01-22        1  AA                ALCOA CORP
# 43   27638    1 2024-01-23        1  AA                ALCOA CORP
# 44   27638    1 2024-01-24        1  AA                ALCOA CORP
# 45   27638    1 2024-01-25        1  AA                ALCOA CORP
# 46   27638    1 2024-01-26        1  AA                ALCOA CORP
# 47   27638    1 2024-01-29        1  AA                ALCOA CORP
# 48   27638    1 2024-01-30        1  AA                ALCOA CORP
# 49   27638    1 2024-01-31        1  AA                ALCOA CORP
# 50   27638    1 2024-02-01        1  AA                ALCOA CORP
# 51   27638    1 2024-02-02        1  AA                ALCOA CORP
# 52   27638    1 2024-02-05        1  AA                ALCOA CORP
# 53   27638    1 2024-02-06        1  AA                ALCOA CORP
# 54   27638    1 2024-02-07        1  AA                ALCOA CORP
# 55   27638    1 2024-02-08        1  AA                ALCOA CORP
# 56   27638    1 2024-02-09        1  AA                ALCOA CORP
# 57   27638    1 2024-02-12        1  AA                ALCOA CORP
#
#           cshoc      cshtrd   eps   prccd     prchd     prcld   prcod   sic  \
# 0   293004000.0   1441580.0  4.22  138.75  140.5900  137.9100  138.19  3826
# 1   293004000.0   2074454.0  4.22  131.16  138.0000  131.0650  138.00  3826
# 2   293004000.0   2446585.0  4.22  131.00  131.4950  130.1900  130.55  3826
# 3   293004000.0   1393963.0  4.22  130.56  131.9600  128.6200  130.00  3826
# 4   293004000.0   1311358.0  4.22  133.38  133.5700  129.8100  130.14  3826
# 5   293004000.0   1434952.0  4.22  130.68  135.6450  130.0100  132.27  3826
# 6   293004000.0   1326296.0  4.22  131.09  131.1600  128.3600  130.58  3826
# 7   293004000.0   2060521.0  4.22  129.68  130.6800  127.9000  130.58  3826
# 8   293004000.0   1285203.0  4.22  130.54  131.6100  129.6400  130.31  3826
# 9   293004000.0   1382120.0  4.22  130.53  130.8100  128.5950  129.14  3826
# 10  293004000.0   1257359.0  4.22  128.12  130.6100  126.7400  129.98  3826
# 11  293004000.0   1404794.0  4.22  130.46  130.7300  127.5340  128.02  3826
# 12  293004000.0   1523311.0  4.22  131.22  131.9900  129.2050  130.17  3826
# 13  293004000.0   1512329.0  4.22  132.55  132.7300  131.2500  131.50  3826
# 14  293004000.0    854928.0  4.22  131.64  133.9400  130.3298  133.64  3826
# 15  293004000.0   1141942.0  4.22  129.78  132.8000  129.4300  132.41  3826
# 16  293004000.0   1120939.0  4.22  129.88  131.4300  129.4300  131.11  3826
# 17  293004000.0   1319766.0  4.22  130.99  134.2300  130.6400  133.71  3826
# 18  293004000.0   1407239.0  4.22  132.83  132.9000  131.2800  131.75  3826
# 19  293004000.0   1428559.0  4.22  134.28  134.5200  132.6900  132.83  3826
# 20  293004000.0   1101380.0  4.22  130.10  134.6200  129.9960  134.61  3826
# 21  293004000.0    862025.0  4.22  133.05  133.0500  129.2605  130.06  3826
# 22  293004000.0   1066280.0  4.22  132.97  133.9200  130.3100  131.84  3826
# 23  293004000.0   2374506.0  4.22  132.82  134.9500  132.3800  132.74  3826
# 24  293004000.0   1766560.0  4.22  135.86  136.1000  131.0750  132.65  3826
# 25  293004000.0   1757979.0  4.22  132.79  136.9100  132.3400  136.52  3826
# 26  293004000.0   1352523.0  4.22  134.07  134.8200  132.1300  132.42  3826
# 27  293004000.0    909735.0  4.22  133.34  135.2300  132.7600  133.93  3826
# 28  293004000.0   1231831.0  4.22  132.31  133.2800  130.3800  133.28  3826
# 29  178472000.0   3833590.0 -4.99   33.31   33.9700   33.0400   33.53  3334
# 30  178472000.0   8244211.0 -4.99   31.49   32.2700   31.0450   32.12  3334
# 31  178472000.0   4541684.0 -4.99   31.13   31.4900   30.8600   31.13  3334
# 32  178472000.0   7312913.0 -4.99   32.13   32.3050   30.0900   30.54  3334
# 33  178472000.0   4989735.0 -4.99   31.73   32.0900   31.2200   31.82  3334
# 34  178472000.0   5790695.0 -4.99   31.94   32.4500   31.5500   31.82  3334
# 35  178472000.0   4732916.0 -4.99   31.65   32.1400   31.3100   31.80  3334
# 36  178472000.0   4418615.0 -4.99   30.88   31.6400   30.6600   31.49  3334
# 37  178472000.0   3933463.0 -4.99   30.03   31.8200   30.0200   31.19  3334
# 38  178472000.0  10702690.0 -4.99   27.87   29.2900   27.2750   29.17  3334
# 39  178472000.0   9513548.0 -4.99   27.18   27.6700   27.0500   27.17  3334
# 40  178472000.0  12848060.0 -4.99   26.75   28.7200   26.5800   27.62  3334
# 41  178472000.0   5999735.0 -4.99   27.36   27.3800   26.3450   26.73  3334
# 42  178472000.0   5706402.0 -4.99   27.62   27.8552   26.7700   26.87  3334
# 43  178472000.0   9352478.0 -4.99   29.51   30.4850   29.0301   29.15  3334
# 44  178472000.0   8913678.0 -4.99   29.76   30.3700   29.3200   30.25  3334
# 45  178472000.0   4682919.0 -4.99   29.88   30.4500   29.2100   29.96  3334
# 46  178472000.0   5118584.0 -4.99   30.61   30.7000   29.8707   30.22  3334
# 47  178472000.0   4646308.0 -4.99   30.91   30.9700   29.6894   30.46  3334
# 48  178472000.0   4712616.0 -4.99   30.61   30.8400   30.0000   30.34  3334
# 49  178472000.0   5757512.0 -4.99   29.75   31.3600   29.7150   30.49  3334
# 50  178472000.0   4168076.0 -4.99   29.69   30.4050   29.1500   30.08  3334
# 51  178472000.0   4954019.0 -4.99   29.49   29.7200   28.5500   29.00  3334
# 52  178472000.0   8809806.0 -4.99   26.84   28.6000   26.7400   28.60  3334
# 53  178472000.0   7827725.0 -4.99   27.62   27.7900   26.9300   26.94  3334
# 54  178472000.0   5013950.0 -4.99   27.53   27.7650   26.9300   27.60  3334
# 55  178472000.0   4853151.0 -4.99   27.71   28.0700   27.1400   27.44  3334
# 56  178472000.0   4758927.0 -4.99   26.89   27.7340   26.7000   27.71  3334
# 57  178472000.0   4370933.0 -4.99   27.90   28.0950   26.8700   27.10  3334
#
#        ret_d
# 0  -0.054703
# 1  -0.001220
# 2  -0.003359
# 3   0.021599
# 4  -0.020243
# 5   0.003137
# 6  -0.010756
# 7   0.006632
# 8  -0.000077
# 9  -0.018463
# 10  0.018264
# 11  0.005826
# 12  0.010136
# 13 -0.006865
# 14 -0.014129
# 15  0.000771
# 16  0.008546
# 17  0.014047
# 18  0.010916
# 19 -0.031129
# 20  0.022675
# 21 -0.000601
# 22 -0.001128
# 23  0.022888
# 24 -0.022597
# 25  0.009639
# 26 -0.005445
# 27 -0.007725
# 28  0.000000
# 29 -0.054638
# 30 -0.011432
# 31  0.032123
# 32 -0.012449
# 33  0.006618
# 34 -0.009080
# 35 -0.024329
# 36 -0.027526
# 37 -0.071928
# 38 -0.024758
# 39 -0.015820
# 40  0.022804
# 41  0.009503
# 42  0.068429
# 43  0.008472
# 44  0.004032
# 45  0.024431
# 46  0.009801
# 47 -0.009706
# 48 -0.028095
# 49 -0.002017
# 50 -0.006736
# 51 -0.089861
# 52  0.029061
# 53 -0.003259
# 54  0.006538
# 55 -0.029592
# 56  0.037560
# 57  0.000000

# %%
# All traded days in this dataset
all_days = list(data['datadate'].unique())
nt = len(tickers)

# Organize y_train as categorical data and use cross entropy instead of sparse cross entropy
def prepare_data(data, seq_length):
    # Block 1: standardize all data cross-sectionally
    # data_sd = data[factors + ['datadate']].groupby('datadate').transform(lambda x: (x - x.mean()) / x.std())
    # data[factors] = data_sd
    # Block 2: cross sectional and per ticker
    # Cross-sectional standardization
    data_cs = data[['cshoc', 'cshtrd', 'eps', 'datadate']].groupby('datadate').transform(lambda x: (x - x.mean()) / x.std())
    # Tic-level standardization
    data_ts = data[['prccd', 'prchd', 'prcld', 'prcod', 'tic']].groupby('tic').transform(lambda x: (x - x.mean()) / x.std())
    data[['cshoc', 'cshtrd', 'eps']] = data_cs
    data[['prccd', 'prchd', 'prcld', 'prcod']] = data_ts
    print(f'Confirm that standardization did not create NaNs: {data.columns[data.isnull().sum() != 0]}')
    
    # Separate training data to construct the rank column
    data_train = data[data['datadate'] != pd.to_datetime(all_days[-1])].reset_index(drop=True)
    
    # Compute how many training data we will have
    # Testing data are always the last day
    num_train_data = (num_of_ts - seq_length) * nt
    num_test_data = nt
    
    # Create ret_d_rank column as labels
    data_train['ret_d_DistinctRank'] = data_train.groupby('datadate')['ret_d'].rank(method='first')
    data_train['ret_d_rank'] = data_train.groupby('datadate')['ret_d_DistinctRank'].transform(
                                                                            lambda x: pd.qcut(x, 10, labels=range(10)))
    # Uncomment the next two lines for imbalanced class setup
    #data_train['ret_d_rank'] = data_train['ret_d_rank'].replace(range(2, 8), 2)
    #data_train['ret_d_rank'] = data_train['ret_d_rank'].replace({8: 3, 9: 4})
    
    # Create training data
    x_train = np.zeros((num_train_data, len(factors), seq_length))
    y_train = np.zeros((num_train_data, ))
    for i in range(num_of_ts - seq_length):
        train_days = all_days[i : seq_length + i]
        data_temp = data_train[data_train['datadate'].isin(train_days)]
        # Convert dataframe data to three dimensional training data (ticker, factor, time-series data)
        # This is 'channels_first' type of data in training!; will change to channel last later!
        pivot_data = data_temp[factors+['datadate', 'tic']].pivot_table(index='tic', columns='datadate')
        x_train[i*nt:(i+1)*nt, :, :] = pivot_data.values.reshape(nt, len(factors), seq_length)
        y_train[i*nt:(i+1)*nt] = data_train[data_train['datadate'] == train_days[-1]]['ret_d_rank'].values.reshape(nt, )
    
    # Create testing data
    test_days = all_days[num_of_ts-seq_length:]
    data_temp = data[data['datadate'].isin(test_days)]
    pivot_data = data_temp[factors+['datadate', 'tic']].pivot_table(index='tic', columns='datadate')
    x_test = pivot_data.values.reshape(num_test_data, len(factors), seq_length)
    
    # Reshape train/test data so that it is channels_last
    x_train = np.transpose(x_train, (0, 2, 1))
    x_test = np.transpose(x_test, (0, 2, 1))
    
    assert x_train.shape[0] == num_train_data
    assert x_test.shape[0] == num_test_data
    
    print(f'Training data have shape {x_train.shape}, {y_train.shape}')
    print(f'Testing data have shape {x_test.shape}')
    
    # Can consider returning data_train; data has no rank column
    return data, data_train, x_train, y_train, x_test # Returned data is standardized

data, data_train, x_train, y_train, x_test = prepare_data(data, seq_length)
# Out:
# Confirm that standardization did not create NaNs: Index([], dtype='object')
# Training data have shape (40428, 20, 7), (40428,)
# Testing data have shape (4492, 20, 7)

# %%
y_train

# %% [markdown]
# # Train CNN

# %%
dropout_rate = 0.2

def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    # Block 1: easy architecture
#     x = keras.layers.Conv1D(filters=8, kernel_size=3, padding="same")(input_layer)
#     x = keras.layers.BatchNormalization()(x)
#     x = keras.layers.ReLU()(x)
#     x = keras.layers.Dropout(dropout_rate)(x)
#     x = keras.layers.Conv1D(filters=32, kernel_size=3, padding="same")(x)
#     x = keras.layers.BatchNormalization()(x)
#     x = keras.layers.ReLU()(x)
#     x = keras.layers.Dropout(dropout_rate)(x)
#     x = keras.layers.GlobalAveragePooling1D()(x)
    
    # Block 2: medium architecture
    x = keras.layers.Conv1D(filters=32, kernel_size=5, padding="same")(input_layer)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.ReLU()(x)
    x = keras.layers.Dropout(dropout_rate)(x)

    x = keras.layers.Conv1D(filters=64, kernel_size=5, padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.ReLU()(x)
    x = keras.layers.Dropout(dropout_rate)(x)

    x = keras.layers.Conv1D(filters=128, kernel_size=5, padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.ReLU()(x)
    x = keras.layers.Dropout(dropout_rate)(x)
    x = keras.layers.GlobalAveragePooling1D()(x)
    
    # Uses softmax here because the output is a distribution of the two classes
    x = keras.layers.Dense(64, activation='relu')(x)
    x = keras.layers.Dropout(dropout_rate)(x)
    x = keras.layers.Dense(16, activation='relu')(x)
    x = keras.layers.Dropout(dropout_rate)(x)
    output_layer = keras.layers.Dense(num_of_classes, activation="softmax")(x)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])

# %%
epochs = 500
batch_size = 128
lr_val = 1e-3

# TRAINS FOR LONG DUE TO DOUBLE DESCENT?
callbacks = [
    # Saves the best model according to val_loss; check at every iteration
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    # Reduce the learning rate by the factor if val_loss does not improve after 20 iterations
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=30, min_lr=1e-5
    ),
    # Stops training if validation does not improve after 50 iterations
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=100, verbose=1),
]

# Uncomment the following for imbalanced class setup
# class_weights = {0: 100, 1: 100, 2: 1, 3: 100, 4: 100}
# unweighted_loss = tf.keras.losses.SparseCategoricalCrossentropy()
# Define customized sparse cross entropy with class weights
# def weighted_loss(y_true, y_pred):
#     loss = unweighted_loss(y_true, y_pred)
#     class_weights_tensor = tf.constant(list(class_weights.values()), dtype=tf.float32)
#     weights = tf.gather(class_weights_tensor, tf.cast(y_true, dtype=tf.int32))
#     weighted_loss = loss * weights
#     return weighted_loss

model.compile(
    optimizer=keras.optimizers.Adam(lr_val),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    # imbalanced class setup
    #loss=weighted_loss,
    metrics=["sparse_categorical_accuracy"]
)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 20, 7)]           0
#
#  conv1d_3 (Conv1D)           (None, 20, 32)            1152
#
#  batch_normalization_3 (Batc  (None, 20, 32)           128
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 20, 32)            0
#
#  dropout_5 (Dropout)         (None, 20, 32)            0
#
#  conv1d_4 (Conv1D)           (None, 20, 64)            10304
#
#  batch_normalization_4 (Batc  (None, 20, 64)           256
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 20, 64)            0
#
#  dropout_6 (Dropout)         (None, 20, 64)            0
#
#  conv1d_5 (Conv1D)           (None, 20, 128)           41088
#
#  batch_normalization_5 (Batc  (None, 20, 128)          512
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 20, 128)           0
#
#  dropout_7 (Dropout)         (None, 20, 128)           0
#
#  global_average_pooling1d_1   (None, 128)              0
#  (GlobalAveragePooling1D)
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 16)                1040
#
#  dropout_9 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 62,906
# Trainable params: 62,458
# Non-trainable params: 448
# _________________________________________________________________

# %%
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 253/253 [==============================] - 7s 22ms/step - loss: 2.2882 - sparse_categorical_accuracy: 0.1224 - val_loss: 2.2895 - val_sparse_categorical_accuracy: 0.1386 - lr: 0.0010
# Epoch 2/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.2561 - sparse_categorical_accuracy: 0.1509 - val_loss: 2.2565 - val_sparse_categorical_accuracy: 0.1456 - lr: 0.0010
# Epoch 3/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.2194 - sparse_categorical_accuracy: 0.1697 - val_loss: 2.2456 - val_sparse_categorical_accuracy: 0.1592 - lr: 0.0010
# Epoch 4/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.1931 - sparse_categorical_accuracy: 0.1784 - val_loss: 2.2444 - val_sparse_categorical_accuracy: 0.1506 - lr: 0.0010
# Epoch 5/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.1794 - sparse_categorical_accuracy: 0.1820 - val_loss: 2.2500 - val_sparse_categorical_accuracy: 0.1572 - lr: 0.0010
# Epoch 6/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.1683 - sparse_categorical_accuracy: 0.1867 - val_loss: 2.2136 - val_sparse_categorical_accuracy: 0.1673 - lr: 0.0010
# Epoch 7/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.1578 - sparse_categorical_accuracy: 0.1898 - val_loss: 2.2523 - val_sparse_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 8/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.1505 - sparse_categorical_accuracy: 0.1993 - val_loss: 2.1807 - val_sparse_categorical_accuracy: 0.1781 - lr: 0.0010
# Epoch 9/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.1461 - sparse_categorical_accuracy: 0.1951 - val_loss: 2.1922 - val_sparse_categorical_accuracy: 0.1787 - lr: 0.0010
# Epoch 10/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.1384 - sparse_categorical_accuracy: 0.2025 - val_loss: 2.1958 - val_sparse_categorical_accuracy: 0.1765 - lr: 0.0010
# Epoch 11/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.1346 - sparse_categorical_accuracy: 0.2032 - val_loss: 2.1826 - val_sparse_categorical_accuracy: 0.1794 - lr: 0.0010
# Epoch 12/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.1282 - sparse_categorical_accuracy: 0.2082 - val_loss: 2.1813 - val_sparse_categorical_accuracy: 0.1893 - lr: 0.0010
# Epoch 13/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.1312 - sparse_categorical_accuracy: 0.2036 - val_loss: 2.2155 - val_sparse_categorical_accuracy: 0.1762 - lr: 0.0010
# Epoch 14/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.1227 - sparse_categorical_accuracy: 0.2077 - val_loss: 2.2060 - val_sparse_categorical_accuracy: 0.1751 - lr: 0.0010
# Epoch 15/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.1215 - sparse_categorical_accuracy: 0.2097 - val_loss: 2.2334 - val_sparse_categorical_accuracy: 0.1595 - lr: 0.0010
# Epoch 16/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.1200 - sparse_categorical_accuracy: 0.2096 - val_loss: 2.2110 - val_sparse_categorical_accuracy: 0.1717 - lr: 0.0010
# Epoch 17/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.1207 - sparse_categorical_accuracy: 0.2082 - val_loss: 2.2837 - val_sparse_categorical_accuracy: 0.1637 - lr: 0.0010
# Epoch 18/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.1133 - sparse_categorical_accuracy: 0.2080 - val_loss: 2.2629 - val_sparse_categorical_accuracy: 0.1620 - lr: 0.0010
# Epoch 19/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.1146 - sparse_categorical_accuracy: 0.2115 - val_loss: 2.2068 - val_sparse_categorical_accuracy: 0.1747 - lr: 0.0010
# Epoch 20/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.1080 - sparse_categorical_accuracy: 0.2123 - val_loss: 2.1808 - val_sparse_categorical_accuracy: 0.1849 - lr: 0.0010
# Epoch 21/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.1080 - sparse_categorical_accuracy: 0.2115 - val_loss: 2.1913 - val_sparse_categorical_accuracy: 0.1756 - lr: 0.0010
# Epoch 22/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.1010 - sparse_categorical_accuracy: 0.2181 - val_loss: 2.1871 - val_sparse_categorical_accuracy: 0.1801 - lr: 0.0010
# Epoch 23/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.1042 - sparse_categorical_accuracy: 0.2146 - val_loss: 2.1929 - val_sparse_categorical_accuracy: 0.1757 - lr: 0.0010
# Epoch 24/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.1008 - sparse_categorical_accuracy: 0.2159 - val_loss: 2.2423 - val_sparse_categorical_accuracy: 0.1678 - lr: 0.0010
# Epoch 25/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.1002 - sparse_categorical_accuracy: 0.2158 - val_loss: 2.1904 - val_sparse_categorical_accuracy: 0.1782 - lr: 0.0010
# Epoch 26/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0966 - sparse_categorical_accuracy: 0.2166 - val_loss: 2.1671 - val_sparse_categorical_accuracy: 0.1874 - lr: 0.0010
# Epoch 27/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.0976 - sparse_categorical_accuracy: 0.2192 - val_loss: 2.1956 - val_sparse_categorical_accuracy: 0.1808 - lr: 0.0010
# Epoch 28/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.0968 - sparse_categorical_accuracy: 0.2163 - val_loss: 2.1840 - val_sparse_categorical_accuracy: 0.1876 - lr: 0.0010
# Epoch 29/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0909 - sparse_categorical_accuracy: 0.2155 - val_loss: 2.1706 - val_sparse_categorical_accuracy: 0.1880 - lr: 0.0010
# Epoch 30/500
# 253/253 [==============================] - 7s 28ms/step - loss: 2.0904 - sparse_categorical_accuracy: 0.2183 - val_loss: 2.2374 - val_sparse_categorical_accuracy: 0.1713 - lr: 0.0010
# Epoch 31/500
# 253/253 [==============================] - 9s 34ms/step - loss: 2.0888 - sparse_categorical_accuracy: 0.2186 - val_loss: 2.1774 - val_sparse_categorical_accuracy: 0.1866 - lr: 0.0010
# Epoch 32/500
# 253/253 [==============================] - 8s 31ms/step - loss: 2.0882 - sparse_categorical_accuracy: 0.2202 - val_loss: 2.1783 - val_sparse_categorical_accuracy: 0.1792 - lr: 0.0010
# Epoch 33/500
# 253/253 [==============================] - 6s 25ms/step - loss: 2.0896 - sparse_categorical_accuracy: 0.2196 - val_loss: 2.2201 - val_sparse_categorical_accuracy: 0.1764 - lr: 0.0010
# Epoch 34/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0861 - sparse_categorical_accuracy: 0.2218 - val_loss: 2.2011 - val_sparse_categorical_accuracy: 0.1807 - lr: 0.0010
# Epoch 35/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.0832 - sparse_categorical_accuracy: 0.2263 - val_loss: 2.1799 - val_sparse_categorical_accuracy: 0.1845 - lr: 0.0010
# Epoch 36/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.0840 - sparse_categorical_accuracy: 0.2242 - val_loss: 2.1884 - val_sparse_categorical_accuracy: 0.1819 - lr: 0.0010
# Epoch 37/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0808 - sparse_categorical_accuracy: 0.2243 - val_loss: 2.1821 - val_sparse_categorical_accuracy: 0.1862 - lr: 0.0010
# Epoch 38/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0788 - sparse_categorical_accuracy: 0.2269 - val_loss: 2.2241 - val_sparse_categorical_accuracy: 0.1724 - lr: 0.0010
# Epoch 39/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.0771 - sparse_categorical_accuracy: 0.2197 - val_loss: 2.1817 - val_sparse_categorical_accuracy: 0.1829 - lr: 0.0010
# Epoch 40/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0759 - sparse_categorical_accuracy: 0.2249 - val_loss: 2.1812 - val_sparse_categorical_accuracy: 0.1815 - lr: 0.0010
# Epoch 41/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.0725 - sparse_categorical_accuracy: 0.2266 - val_loss: 2.2103 - val_sparse_categorical_accuracy: 0.1814 - lr: 0.0010
# Epoch 42/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.0725 - sparse_categorical_accuracy: 0.2237 - val_loss: 2.2416 - val_sparse_categorical_accuracy: 0.1754 - lr: 0.0010
# Epoch 43/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0746 - sparse_categorical_accuracy: 0.2245 - val_loss: 2.2106 - val_sparse_categorical_accuracy: 0.1757 - lr: 0.0010
# Epoch 44/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0706 - sparse_categorical_accuracy: 0.2275 - val_loss: 2.2017 - val_sparse_categorical_accuracy: 0.1815 - lr: 0.0010
# Epoch 45/500
# 253/253 [==============================] - 6s 25ms/step - loss: 2.0672 - sparse_categorical_accuracy: 0.2278 - val_loss: 2.1983 - val_sparse_categorical_accuracy: 0.1832 - lr: 0.0010
# Epoch 46/500
# 253/253 [==============================] - 8s 33ms/step - loss: 2.0719 - sparse_categorical_accuracy: 0.2275 - val_loss: 2.2128 - val_sparse_categorical_accuracy: 0.1806 - lr: 0.0010
# Epoch 47/500
# 253/253 [==============================] - 7s 26ms/step - loss: 2.0692 - sparse_categorical_accuracy: 0.2275 - val_loss: 2.2194 - val_sparse_categorical_accuracy: 0.1775 - lr: 0.0010
# Epoch 48/500
# 253/253 [==============================] - 6s 26ms/step - loss: 2.0700 - sparse_categorical_accuracy: 0.2269 - val_loss: 2.1750 - val_sparse_categorical_accuracy: 0.1886 - lr: 0.0010
# Epoch 49/500
# 253/253 [==============================] - 6s 25ms/step - loss: 2.0638 - sparse_categorical_accuracy: 0.2307 - val_loss: 2.2268 - val_sparse_categorical_accuracy: 0.1674 - lr: 0.0010
# Epoch 50/500
# 253/253 [==============================] - 6s 25ms/step - loss: 2.0620 - sparse_categorical_accuracy: 0.2291 - val_loss: 2.1781 - val_sparse_categorical_accuracy: 0.1885 - lr: 0.0010
# Epoch 51/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.0634 - sparse_categorical_accuracy: 0.2303 - val_loss: 2.2449 - val_sparse_categorical_accuracy: 0.1694 - lr: 0.0010
# Epoch 52/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.0636 - sparse_categorical_accuracy: 0.2280 - val_loss: 2.2076 - val_sparse_categorical_accuracy: 0.1745 - lr: 0.0010
# Epoch 53/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0630 - sparse_categorical_accuracy: 0.2303 - val_loss: 2.1778 - val_sparse_categorical_accuracy: 0.1885 - lr: 0.0010
# Epoch 54/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.0600 - sparse_categorical_accuracy: 0.2298 - val_loss: 2.1898 - val_sparse_categorical_accuracy: 0.1861 - lr: 0.0010
# Epoch 55/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0604 - sparse_categorical_accuracy: 0.2286 - val_loss: 2.1807 - val_sparse_categorical_accuracy: 0.1867 - lr: 0.0010
# Epoch 56/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0594 - sparse_categorical_accuracy: 0.2301 - val_loss: 2.2513 - val_sparse_categorical_accuracy: 0.1736 - lr: 0.0010
# Epoch 57/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.0470 - sparse_categorical_accuracy: 0.2361 - val_loss: 2.2004 - val_sparse_categorical_accuracy: 0.1791 - lr: 5.0000e-04
# Epoch 58/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0465 - sparse_categorical_accuracy: 0.2335 - val_loss: 2.2013 - val_sparse_categorical_accuracy: 0.1807 - lr: 5.0000e-04
# Epoch 59/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0464 - sparse_categorical_accuracy: 0.2361 - val_loss: 2.1882 - val_sparse_categorical_accuracy: 0.1844 - lr: 5.0000e-04
# Epoch 60/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0435 - sparse_categorical_accuracy: 0.2327 - val_loss: 2.1618 - val_sparse_categorical_accuracy: 0.1912 - lr: 5.0000e-04
# Epoch 61/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0462 - sparse_categorical_accuracy: 0.2371 - val_loss: 2.1827 - val_sparse_categorical_accuracy: 0.1822 - lr: 5.0000e-04
# Epoch 62/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0459 - sparse_categorical_accuracy: 0.2371 - val_loss: 2.2144 - val_sparse_categorical_accuracy: 0.1809 - lr: 5.0000e-04
# Epoch 63/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0413 - sparse_categorical_accuracy: 0.2380 - val_loss: 2.1552 - val_sparse_categorical_accuracy: 0.1901 - lr: 5.0000e-04
# Epoch 64/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.0453 - sparse_categorical_accuracy: 0.2372 - val_loss: 2.2002 - val_sparse_categorical_accuracy: 0.1760 - lr: 5.0000e-04
# Epoch 65/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.0427 - sparse_categorical_accuracy: 0.2350 - val_loss: 2.1824 - val_sparse_categorical_accuracy: 0.1820 - lr: 5.0000e-04
# Epoch 66/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0406 - sparse_categorical_accuracy: 0.2369 - val_loss: 2.1737 - val_sparse_categorical_accuracy: 0.1859 - lr: 5.0000e-04
# Epoch 67/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0401 - sparse_categorical_accuracy: 0.2368 - val_loss: 2.2015 - val_sparse_categorical_accuracy: 0.1815 - lr: 5.0000e-04
# Epoch 68/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.0435 - sparse_categorical_accuracy: 0.2369 - val_loss: 2.2072 - val_sparse_categorical_accuracy: 0.1798 - lr: 5.0000e-04
# Epoch 69/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0409 - sparse_categorical_accuracy: 0.2379 - val_loss: 2.2000 - val_sparse_categorical_accuracy: 0.1770 - lr: 5.0000e-04
# Epoch 70/500
# 253/253 [==============================] - 5s 20ms/step - loss: 2.0372 - sparse_categorical_accuracy: 0.2384 - val_loss: 2.2015 - val_sparse_categorical_accuracy: 0.1833 - lr: 5.0000e-04
# Epoch 71/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0400 - sparse_categorical_accuracy: 0.2393 - val_loss: 2.1855 - val_sparse_categorical_accuracy: 0.1843 - lr: 5.0000e-04
# Epoch 72/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0395 - sparse_categorical_accuracy: 0.2399 - val_loss: 2.1650 - val_sparse_categorical_accuracy: 0.1864 - lr: 5.0000e-04
# Epoch 73/500
# 253/253 [==============================] - 5s 20ms/step - loss: 2.0346 - sparse_categorical_accuracy: 0.2408 - val_loss: 2.2007 - val_sparse_categorical_accuracy: 0.1820 - lr: 5.0000e-04
# Epoch 74/500
# 253/253 [==============================] - 6s 23ms/step - loss: 2.0387 - sparse_categorical_accuracy: 0.2388 - val_loss: 2.1889 - val_sparse_categorical_accuracy: 0.1869 - lr: 5.0000e-04
# Epoch 75/500
# 253/253 [==============================] - 6s 24ms/step - loss: 2.0380 - sparse_categorical_accuracy: 0.2384 - val_loss: 2.2208 - val_sparse_categorical_accuracy: 0.1835 - lr: 5.0000e-04
# Epoch 76/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0374 - sparse_categorical_accuracy: 0.2383 - val_loss: 2.1825 - val_sparse_categorical_accuracy: 0.1888 - lr: 5.0000e-04
# Epoch 77/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0349 - sparse_categorical_accuracy: 0.2400 - val_loss: 2.1575 - val_sparse_categorical_accuracy: 0.1937 - lr: 5.0000e-04
# Epoch 78/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0359 - sparse_categorical_accuracy: 0.2389 - val_loss: 2.1497 - val_sparse_categorical_accuracy: 0.1942 - lr: 5.0000e-04
# Epoch 79/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0336 - sparse_categorical_accuracy: 0.2386 - val_loss: 2.1973 - val_sparse_categorical_accuracy: 0.1801 - lr: 5.0000e-04
# Epoch 80/500
# 253/253 [==============================] - 5s 22ms/step - loss: 2.0322 - sparse_categorical_accuracy: 0.2385 - val_loss: 2.1817 - val_sparse_categorical_accuracy: 0.1829 - lr: 5.0000e-04
# Epoch 81/500
# 253/253 [==============================] - 5s 21ms/step - loss: 2.0350 - sparse_categorical_accuracy: 0.2380 - val_loss: 2.2395 - val_sparse_categorical_accuracy: 0.1709 - lr: 5.0000e-04
# Epoch 82/500
# 253/253 [==============================] - 5s 20ms/step - loss: 2.0348 - sparse_categorical_accuracy: 0.2399 - val_loss: 2.2217 - val_sparse_categorical_accuracy: 0.1776 - lr: 5.0000e-04
# Epoch 83/500
# 253/253 [==============================] - 6s 22ms/step - loss: 2.0310 - sparse_categorical_accuracy: 0.2404 - val_loss: 2.1871 - val_sparse_categorical_accuracy: 0.1840 - lr: 5.0000e-04
# Epoch 84/500
#  37/253 [===>..........................] - ETA: 4s - loss: 2.0209 - sparse_categorical_accuracy: 0.2348

# %%
model.evaluate(x_train, y_train)
# Out:
# 1264/1264 [==============================] - 3s 3ms/step - loss: 1.7696 - sparse_categorical_accuracy: 0.4014
# [1.7696388959884644, 0.401355504989624]

# %%
y_test = model.predict(x_test)
# Out:
# 141/141 [==============================] - 1s 3ms/step

# %%
y_test
# Out:
# array([[1.30739296e-03, 1.55903816e-01, 2.69877225e-01, ...,
#         4.26670816e-03, 4.55418522e-05, 7.30647498e-09],
#        [5.99381565e-05, 3.17508588e-04, 5.22353628e-04, ...,
#         8.01815018e-02, 1.60056069e-01, 7.15331435e-01],
#        [3.85021508e-01, 5.55361882e-02, 1.89883802e-02, ...,
#         2.27699485e-02, 5.02580442e-02, 4.21559781e-01],
#        ...,
#        [7.36839890e-01, 2.38431245e-01, 1.64512992e-02, ...,
#         5.23362178e-06, 1.30959745e-06, 1.15099601e-08],
#        [1.47333443e-01, 3.06170225e-01, 1.74601957e-01, ...,
#         1.93419550e-02, 1.33062778e-02, 5.35129337e-04],
#        [9.63653684e-01, 3.08607519e-02, 1.79932662e-03, ...,
#         1.08039116e-04, 1.27188207e-04, 2.73455244e-05]], dtype=float32)

# %%
for i in range(nt):
    if np.argmax(y_test[i, :]) == 0:
        print(f'{num_to_tic_dict[i]} is top stock')

for i in range(nt):
    if np.argmax(y_test[i, :]) == 9:
        print(f'{num_to_tic_dict[i]} is bottom stock')
        
# For imbalanced class setup
# for i in range(nt):
#     if np.argmax(y_test[i, :]) != 2:
#         print(f'{num_to_tic_dict[i]} is rank {np.argmax(y_test[i, :])} stock')
# Out:
# AA is bottom stock
# AADI is bottom stock
# AAMC is bottom stock
# AAN is bottom stock
# AAON is top stock
# AAP is top stock
# AAU is bottom stock
# ABAT is bottom stock
# ABEO is top stock
# ABG is top stock
# ABL is top stock
# ABLV is bottom stock
# ABNB is top stock
# ABOS is bottom stock
# ABR is bottom stock
# ABSI is top stock
# ABUS is top stock
# ACDC is bottom stock
# ACEL is top stock
# ACGL is top stock
# ACI is bottom stock
# ACIC is top stock
# ACLX is top stock
# ACMR is top stock
# ACNB is bottom stock
# ACON is top stock
# ACRE is bottom stock
# ACRS is top stock
# ACRV is bottom stock
# ACST is bottom stock
# ACTG is top stock
# ACXP is bottom stock
# ADAP is top stock
# ADCT is top stock
# ADD is bottom stock
# ADIL is bottom stock
# ADM is bottom stock
# ADN is bottom stock
# ADP is top stock
# ADPT is bottom stock
# ADTH is top stock
# ADTX is bottom stock
# ADUS is top stock
# ADVM is top stock
# AEHR is bottom stock
# AEI is top stock
# AEMD is bottom stock
# AENT is top stock
# AEO is top stock
# AEON is top stock
# AES is bottom stock
# AEVA is top stock
# AEY is bottom stock
# AEYE is top stock
# AEZS is bottom stock
# AFG is top stock
# AFIB is top stock
# AFRM is bottom stock
# AG is bottom stock
# AGAE is top stock
# AGI is bottom stock
# AGIO is top stock
# AGL is bottom stock
# AGRI is bottom stock
# AGRX is bottom stock
# AGS is top stock
# AGYS is top stock
# AHCO is top stock
# AHG is top stock
# AIHS is top stock
# AIMD is bottom stock
# AIP is top stock
# AIRC is bottom stock
# AIRG is top stock
# AIRI is top stock
# AIU is top stock
# AKA is bottom stock
# AKAM is top stock
# AKBA is top stock
# AKLI is bottom stock
# ALB is bottom stock
# ALBT is bottom stock
# ALCE is bottom stock
# ALCO is top stock
# ALEC is bottom stock
# ALEX is bottom stock
# ALG is top stock
# ALHC is bottom stock
# ALIM is bottom stock
# ALIT is top stock
# ALL is top stock
# ALLE is top stock
# ALLK is bottom stock
# ALLO is top stock
# ALLR is bottom stock
# ALLT is top stock
# ALNY is bottom stock
# ALPN is top stock
# ALPP is bottom stock
# ALRM is top stock
# ALRS is top stock
# ALSN is top stock
# ALTO is bottom stock
# ALV is top stock
# ALVR is top stock
# AM is bottom stock
# AMAT is top stock
# AMC is bottom stock
# AMCX is bottom stock
# AMED is top stock
# AMK is top stock
# AMLI is bottom stock
# AMPE is bottom stock
# AMPG is top stock
# AMPL is top stock
# AMPS is top stock
# AMPY is top stock
# AMRC is bottom stock
# AMRN is top stock
# AMSC is top stock
# AMSWA is bottom stock
# AMWD is top stock
# AN is top stock
# ANAB is top stock
# ANET is top stock
# ANF is top stock
# ANNX is top stock
# ANTX is bottom stock
# ANY is bottom stock
# AONC is bottom stock
# APCX is top stock
# APD is bottom stock
# APG is top stock
# APLD is bottom stock
# APLT is bottom stock
# APO is top stock
# APOG is top stock
# APP is top stock
# APPF is top stock
# APPS is bottom stock
# APT is bottom stock
# APTO is bottom stock
# APTV is top stock
# APVO is bottom stock
# APYX is top stock
# AQMS is bottom stock
# AR is bottom stock
# ARC is bottom stock
# ARCB is top stock
# ARCT is top stock
# ARDS is top stock
# AREC is bottom stock
# AREN is bottom stock
# ARES is top stock
# ARHS is top stock
# ARIS is top stock
# ARL is top stock
# ARLO is bottom stock
# ARMK is top stock
# ARMN is bottom stock
# ARMP is top stock
# AROC is top stock
# ARQ is top stock
# ARQQ is top stock
# ARQT is top stock
# ARVN is top stock
# ARW is bottom stock
# ASAP is top stock
# ASH is top stock
# ASLE is bottom stock
# ASMB is top stock
# ASNS is top stock
# ASO is top stock
# ASPI is top stock
# ASPN is bottom stock
# ASRV is bottom stock
# ASTI is bottom stock
# ASTL is bottom stock
# ASTR is bottom stock
# ASTS is bottom stock
# ASUR is top stock
# ASXC is bottom stock
# ATER is top stock
# ATGE is bottom stock
# ATHA is top stock
# ATIP is top stock
# ATLC is bottom stock
# ATLX is bottom stock
# ATNM is top stock
# ATOM is top stock
# ATR is top stock
# ATRA is top stock
# ATRO is top stock
# ATXI is bottom stock
# ATXS is top stock
# AUGX is bottom stock
# AUID is top stock
# AULT is top stock
# AUMN is bottom stock
# AUPH is bottom stock
# AUST is top stock
# AUTL is top stock
# AUUD is bottom stock
# AVD is top stock
# AVDL is top stock
# AVDX is top stock
# AVRO is bottom stock
# AVT is bottom stock
# AVTX is bottom stock
# AVXL is top stock
# AWI is top stock
# AWIN is bottom stock
# AWRE is top stock
# AXDX is bottom stock
# AXON is top stock
# AXP is top stock
# AXR is bottom stock
# AXS is top stock
# AZEK is top stock
# AZZ is top stock
# B is top stock
# BA is bottom stock
# BACK is bottom stock
# BAER is bottom stock
# BAH is top stock
# BANC is top stock
# BARK is top stock
# BASE is top stock
# BATL is bottom stock
# BBGI is bottom stock
# BBLG is bottom stock
# BBU is top stock
# BCAB is top stock
# BCAL is bottom stock
# BCBP is bottom stock
# BCC is top stock
# BCDA is bottom stock
# BCML is bottom stock
# BCRX is bottom stock
# BCTX is bottom stock
# BDC is top stock
# BDN is bottom stock
# BDSX is bottom stock
# BDTX is top stock
# BEAM is top stock
# BEAT is bottom stock
# BEEM is top stock
# BELFA is top stock
# BELFB is top stock
# BENF is bottom stock
# BEP is bottom stock
# BERY is bottom stock
# BETR is bottom stock
# BETS is top stock
# BF.B is top stock
# BFH is top stock
# BFI is bottom stock
# BFRI is bottom stock
# BGC is top stock
# BGI is bottom stock
# BGS is top stock
# BGXX is bottom stock
# BHE is top stock
# BHIL is top stock
# BHM is bottom stock
# BHP is bottom stock
# BHR is bottom stock
# BHVN is top stock
# BIG is bottom stock
# BILL is bottom stock
# BIMI is top stock
# BIOL is bottom stock
# BIOR is bottom stock
# BITF is bottom stock
# BIVI is bottom stock
# BJDX is bottom stock
# BJRI is top stock
# BK is top stock
# BKD is top stock
# BKKT is bottom stock
# BKNG is top stock
# BKR is bottom stock
# BKSY is top stock
# BKYI is bottom stock
# BLBD is top stock
# BLCM is bottom stock
# BLND is top stock
# BLNK is bottom stock
# BLUE is bottom stock
# BLZE is top stock
# BMEA is top stock
# BMRA is bottom stock
# BMRC is bottom stock
# BMRN is bottom stock
# BNED is bottom stock
# BNGO is bottom stock
# BNZI is bottom stock
# BOLT is bottom stock
# BOOT is top stock
# BORR is top stock
# BOX is top stock
# BOXL is bottom stock
# BQ is bottom stock
# BRBR is top stock
# BRBS is bottom stock
# BRC is top stock
# BRCC is top stock
# BRDG is bottom stock
# BRK.B is top stock
# BRN is bottom stock
# BRNS is bottom stock
# BRT is bottom stock
# BRTX is top stock
# BSGM is top stock
# BSIG is top stock
# BSVN is top stock
# BSX is top stock
# BTAI is bottom stock
# BTBT is bottom stock
# BTCS is bottom stock
# BTCY is bottom stock
# BTOG is top stock
# BTTR is bottom stock
# BTTX is top stock
# BURU is top stock
# BVS is bottom stock
# BWMN is top stock
# BXC is top stock
# BYD is top stock
# BYND is bottom stock
# BYRN is top stock
# BYU is bottom stock
# BZFD is bottom stock
# CABA is top stock
# CACC is top stock
# CACI is top stock
# CAL is top stock
# CAMP is top stock
# CAPR is bottom stock
# CAPT is top stock
# CARA is bottom stock
# CARG is top stock
# CARM is bottom stock
# CARS is top stock
# CASA is bottom stock
# CASS is top stock
# CATX is top stock
# CAUD is bottom stock
# CB is top stock
# CBAT is bottom stock
# CBAY is top stock
# CBL is bottom stock
# CBNK is bottom stock
# CBUS is top stock
# CCCC is top stock
# CCCS is top stock
# CCEL is bottom stock
# CCG is bottom stock
# CCL is bottom stock
# CCLP is top stock
# CDIO is bottom stock
# CDLX is bottom stock
# CDMO is top stock
# CDNA is bottom stock
# CDP is bottom stock
# CDT is bottom stock
# CDTX is bottom stock
# CDW is top stock
# CDXC is top stock
# CEAD is bottom stock
# CECO is top stock
# CEI is bottom stock
# CEIX is bottom stock
# CELC is top stock
# CELU is top stock
# CELZ is bottom stock
# CENT is bottom stock
# CENTA is bottom stock
# CERE is top stock
# CERS is top stock
# CETX is bottom stock
# CETY is bottom stock
# CEVA is top stock
# CFFI is bottom stock
# CFLT is top stock
# CG is top stock
# CGA is bottom stock
# CGAU is bottom stock
# CGC is bottom stock
# CGEM is top stock
# CGTX is top stock
# CHCT is top stock
# CHEF is top stock
# CHGG is bottom stock
# CHMI is bottom stock
# CHPT is top stock
# CHRS is bottom stock
# CHWY is bottom stock
# CIEN is top stock
# CIFR is bottom stock
# CING is bottom stock
# CIO is bottom stock
# CISO is bottom stock
# CIVB is bottom stock
# CIX is top stock
# CJET is bottom stock
# CKPT is bottom stock
# CL is top stock
# CLDI is bottom stock
# CLFD is top stock
# CLIR is bottom stock
# CLMB is top stock
# CLMT is bottom stock
# CLNN is top stock
# CLPR is bottom stock
# CLS is top stock
# CLSK is top stock
# CLVR is top stock
# CLW is bottom stock
# CLX is top stock
# CMAX is top stock
# CMC is top stock
# CMCO is top stock
# CMCT is bottom stock
# CMG is top stock
# CMI is top stock
# CMLS is bottom stock
# CMMB is top stock
# CMND is bottom stock
# CMPO is top stock
# CMPR is top stock
# CMPS is top stock
# CMPX is bottom stock
# CMRA is bottom stock
# CMTG is bottom stock
# CMTL is bottom stock
# CNA is top stock
# CNDA is top stock
# CNET is top stock
# CNK is top stock
# CNM is top stock
# CNSP is bottom stock
# CNTA is top stock
# CNTY is bottom stock
# CNXA is top stock
# COCH is bottom stock
# COCO is bottom stock
# COCP is bottom stock
# CODX is bottom stock
# COEP is bottom stock
# COGT is top stock
# COHR is top stock
# COHU is top stock
# COIN is bottom stock
# COKE is bottom stock
# COLB is bottom stock
# COLL is bottom stock
# COMM is bottom stock
# COMP is top stock
# COOP is top stock
# COR is top stock
# COSM is bottom stock
# COST is top stock
# CPHI is bottom stock
# CPNG is bottom stock
# CPOP is top stock
# CPSH is top stock
# CPSS is bottom stock
# CPTN is bottom stock
# CRBP is top stock
# CRBU is top stock
# CRCT is bottom stock
# CRDO is top stock
# CREX is top stock
# CRGE is bottom stock
# CRI is top stock
# CRIS is bottom stock
# CRK is bottom stock
# CRMD is bottom stock
# CRMT is top stock
# CROX is top stock
# CRS is bottom stock
# CRSP is top stock
# CRTO is top stock
# CRUS is top stock
# CRVO is top stock
# CRWS is top stock
# CSGS is top stock
# CSL is top stock
# CSLR is bottom stock
# CSPI is top stock
# CSSE is bottom stock
# CSTL is top stock
# CSWI is top stock
# CSX is top stock
# CTAS is top stock
# CTKB is top stock
# CTLP is bottom stock
# CTLT is top stock
# CTM is top stock
# CTOS is top stock
# CTRN is top stock
# CTS is top stock
# CTVA is top stock
# CULP is bottom stock
# CURO is bottom stock
# CURV is bottom stock
# CUTR is top stock
# CVBF is bottom stock
# CVCO is top stock
# CVCY is bottom stock
# CVI is top stock
# CVLG is top stock
# CVM is bottom stock
# CVNA is top stock
# CW is top stock
# CWBC is bottom stock
# CWCO is bottom stock
# CWK is top stock
# CXAI is top stock
# CXDO is top stock
# CXW is top stock
# CYAN is bottom stock
# CYCC is top stock
# CYH is top stock
# CYN is top stock
# CYRX is top stock
# CYTH is top stock
# CZFS is bottom stock
# CZNC is bottom stock
# DASH is top stock
# DATS is bottom stock
# DAVE is top stock
# DAWN is top stock
# DBI is top stock
# DBRG is top stock
# DBVT is bottom stock
# DCFC is bottom stock
# DCGO is bottom stock
# DCOM is bottom stock
# DCTH is top stock
# DDS is top stock
# DECA is bottom stock
# DECK is top stock
# DELL is top stock
# DGHI is bottom stock
# DGII is top stock
# DGX is bottom stock
# DHC is bottom stock
# DHR is top stock
# DHX is top stock
# DIBS is top stock
# DINO is top stock
# DIOD is bottom stock
# DIS is top stock
# DKNG is top stock
# DKS is top stock
# DLPN is bottom stock
# DMKPQ is bottom stock
# DMRC is top stock
# DMTK is bottom stock
# DNMR is bottom stock
# DNN is top stock
# DNTH is top stock
# DOCN is top stock
# DOCS is top stock
# DOGZ is bottom stock
# DOMA is bottom stock
# DOMH is bottom stock
# DOMO is top stock
# DOOR is top stock
# DOUG is bottom stock
# DOV is top stock
# DOW is top stock
# DRCT is bottom stock
# DRIO is top stock
# DRMA is bottom stock
# DRRX is top stock
# DRTTF is top stock
# DSGR is top stock
# DSKE is top stock
# DSP is top stock
# DTC is top stock
# DTI is bottom stock
# DTSS is top stock
# DTST is top stock
# DVA is top stock
# DWAC is top stock
# DXYN is bottom stock
# DY is top stock
# DYAI is bottom stock
# DYN is top stock
# DYNT is bottom stock
# DZSI is bottom stock
# EAF is bottom stock
# EAT is top stock
# EB is top stock
# EBET is top stock
# EBS is bottom stock
# ECDA is bottom stock
# ECTM is bottom stock
# EDIT is bottom stock
# EDRY is top stock
# EDSA is top stock
# EDUC is top stock
# EEFT is top stock
# EFX is top stock
# EG is bottom stock
# EGAN is bottom stock
# EGLXF is bottom stock
# EGOX is bottom stock
# EGP is top stock
# EHTH is bottom stock
# EIG is top stock
# EIX is bottom stock
# EJH is top stock
# EKSO is bottom stock
# EL is top stock
# ELBM is top stock
# ELIQ is bottom stock
# ELTK is top stock
# ELTX is bottom stock
# ELV is top stock
# ELVA is top stock
# ELVN is top stock
# ELWS is bottom stock
# EMBC is bottom stock
# EME is top stock
# EMKR is bottom stock
# EMX is bottom stock
# ENDPQ is top stock
# ENG is bottom stock
# ENR is top stock
# ENS is bottom stock
# ENSV is bottom stock
# ENTX is top stock
# ENVA is top stock
# ENVB is bottom stock
# ENZ is bottom stock
# EOLS is top stock
# EOSE is top stock
# EP is bottom stock
# EPC is top stock
# EPR is bottom stock
# EQ is top stock
# EQT is bottom stock
# ERAS is bottom stock
# ERF is top stock
# ERIE is top stock
# ERII is bottom stock
# ESAB is top stock
# ESCA is bottom stock
# ESLA is top stock
# ESOA is top stock
# ESP is top stock
# ESPR is bottom stock
# ESSA is bottom stock
# ETD is top stock
# ETON is bottom stock
# EVA is bottom stock
# EVBG is top stock
# EVC is top stock
# EVER is top stock
# EVEX is bottom stock
# EVGO is bottom stock
# EVH is bottom stock
# EVI is top stock
# EVLO is bottom stock
# EVLV is top stock
# EVOK is bottom stock
# EVTC is top stock
# EVTV is top stock
# EW is top stock
# EWCZ is top stock
# EWTX is top stock
# EXAS is bottom stock
# EXEL is bottom stock
# EXK is bottom stock
# EXP is top stock
# EXPR is bottom stock
# EYPT is top stock
# EZPW is top stock
# FA is top stock
# FANG is top stock
# FARM is top stock
# FARO is top stock
# FAST is top stock
# FAT is top stock
# FATE is top stock
# FATH is bottom stock
# FBIO is bottom stock
# FBMS is bottom stock
# FBRX is bottom stock
# FC is top stock
# FCFS is top stock
# FCUV is bottom stock
# FCX is bottom stock
# FDMT is top stock
# FDP is bottom stock
# FDS is top stock
# FEAM is bottom stock
# FELE is top stock
# FEMY is top stock
# FERG is top stock
# FET is bottom stock
# FFIE is bottom stock
# FFWM is bottom stock
# FG is top stock
# FGBI is bottom stock
# FGEN is top stock
# FGH is bottom stock
# FHTX is top stock
# FI is top stock
# FINW is bottom stock
# FIP is top stock
# FIX is top stock
# FIXX is top stock
# FKWL is bottom stock
# FLGC is bottom stock
# FLGT is bottom stock
# FLL is top stock
# FLNT is bottom stock
# FLUX is bottom stock
# FLXS is top stock
# FLYX is top stock
# FMC is bottom stock
# FMST is top stock
# FN is top stock
# FNA is top stock
# FNCH is bottom stock
# FNF is top stock
# FNGR is bottom stock
# FNKO is top stock
# FNLC is bottom stock
# FNWB is bottom stock
# FOA is bottom stock
# FONR is top stock
# FORM is top stock
# FORR is bottom stock
# FOUR is top stock
# FOX is top stock
# FOXA is top stock
# FOXO is top stock
# FPAY is bottom stock
# FRD is top stock
# FRGE is bottom stock
# FROG is top stock
# FRPT is top stock
# FSBC is bottom stock
# FSBW is bottom stock
# FSEA is top stock
# FSLR is bottom stock
# FSLY is top stock
# FSM is bottom stock
# FSP is bottom stock
# FSR is bottom stock
# FSS is top stock
# FTAI is top stock
# FTCI is top stock
# FTEK is top stock
# FTFT is bottom stock
# FTHM is bottom stock
# FTK is bottom stock
# FTLF is top stock
# FTNT is top stock
# FTV is top stock
# FUBO is bottom stock
# FULC is top stock
# FUN is top stock
# FUNC is bottom stock
# FURY is bottom stock
# FUSN is top stock
# FUV is bottom stock
# FVCB is bottom stock
# FWBI is top stock
# FWRD is bottom stock
# FWRG is top stock
# FXLV is bottom stock
# FYBR is bottom stock
# GAIN is bottom stock
# GANX is top stock
# GATX is top stock
# GBCI is bottom stock
# GBIO is top stock
# GCBC is top stock
# GCMG is top stock
# GCTK is bottom stock
# GD is top stock
# GDC is bottom stock
# GDYN is top stock
# GE is top stock
# GETR is top stock
# GEVO is bottom stock
# GFF is top stock
# GGE is bottom stock
# GH is bottom stock
# GHC is top stock
# GIB is top stock
# GIC is top stock
# GIPR is bottom stock
# GL is top stock
# GLDD is top stock
# GLRE is top stock
# GLSI is bottom stock
# GLT is top stock
# GLTO is bottom stock
# GLW is top stock
# GMBL is bottom stock
# GMDA is top stock
# GMGI is top stock
# GMS is top stock
# GNE is bottom stock
# GNL is bottom stock
# GNLN is bottom stock
# GNLX is bottom stock
# GNPX is top stock
# GNTX is top stock
# GOEV is bottom stock
# GOLD is bottom stock
# GOLF is top stock
# GOOS is top stock
# GORO is bottom stock
# GORV is bottom stock
# GOSS is bottom stock
# GOVX is top stock
# GP is bottom stock
# GPC is top stock
# GPCR is top stock
# GPN is top stock
# GPRO is bottom stock
# GRBK is top stock
# GRC is top stock
# GREE is bottom stock
# GROM is bottom stock
# GROV is bottom stock
# GRPN is top stock
# GRTS is top stock
# GRWG is bottom stock
# GRYP is top stock
# GSBC is bottom stock
# GSHD is top stock
# GT is top stock
# GTBP is top stock
# GTEC is top stock
# GTHX is top stock
# GTLB is top stock
# GTLS is bottom stock
# GURE is bottom stock
# GVP is bottom stock
# GWAV is top stock
# GWW is top stock
# GXAI is bottom stock
# GYRE is bottom stock
# HAIN is bottom stock
# HAYN is top stock
# HBI is top stock
# HCA is top stock
# HCDIQ is bottom stock
# HCI is top stock
# HCKT is top stock
# HCP is top stock
# HE is bottom stock
# HEAR is top stock
# HEES is top stock
# HEI is top stock
# HEI.A is top stock
# HEPA is bottom stock
# HGAS is bottom stock
# HGTY is top stock
# HGV is top stock
# HHH is bottom stock
# HIBB is top stock
# HIG is top stock
# HII is top stock
# HIMS is top stock
# HIPO is top stock
# HITI is top stock
# HIVE is bottom stock
# HIW is top stock
# HL is bottom stock
# HLF is bottom stock
# HLI is top stock
# HLIT is top stock
# HLLY is top stock
# HLNE is top stock
# HLT is top stock
# HLTH is top stock
# HMN is top stock
# HMST is top stock
# HNRA is top stock
# HNRG is bottom stock
# HNST is top stock
# HOFT is top stock
# HOG is top stock
# HOLO is top stock
# HOOK is bottom stock
# HOV is top stock
# HOWL is top stock
# HPCO is bottom stock
# HPK is top stock
# HQI is bottom stock
# HRI is top stock
# HRL is bottom stock
# HROW is top stock
# HRTX is top stock
# HSCS is bottom stock
# HSDT is bottom stock
# HSII is top stock
# HTZ is bottom stock
# HUBB is top stock
# HUBS is top stock
# HUMA is top stock
# HURC is top stock
# HURN is top stock
# HUSA is bottom stock
# HWBK is bottom stock
# HWM is top stock
# HY is top stock
# HYLN is top stock
# HYMC is bottom stock
# HYW is bottom stock
# HZO is bottom stock
# IAS is top stock
# IBEX is bottom stock
# IBIO is bottom stock
# IBKR is top stock
# IBM is top stock
# IBP is top stock
# ICAD is bottom stock
# ICFI is top stock
# ICHR is top stock
# ICU is top stock
# ICVX is bottom stock
# IDAI is bottom stock
# IDEX is bottom stock
# IDICQ is bottom stock
# IDR is top stock
# IDT is top stock
# IDYA is top stock
# IESC is top stock
# IGC is top stock
# IGMS is top stock
# IHRT is top stock
# IKNA is bottom stock
# ILPT is bottom stock
# IMKTA is bottom stock
# IMMR is top stock
# IMMX is bottom stock
# IMNM is top stock
# IMNN is bottom stock
# IMPLQ is bottom stock
# IMRX is bottom stock
# IMUX is bottom stock
# IMVT is bottom stock
# INBK is top stock
# INBS is top stock
# INCR is top stock
# INCY is bottom stock
# INDB is bottom stock
# INDI is top stock
# INDP is bottom stock
# INFN is top stock
# INGN is top stock
# INLX is top stock
# INMB is top stock
# INO is top stock
# INOD is top stock
# INPX is top stock
# INSE is top stock
# INSG is top stock
# INSM is bottom stock
# INSW is top stock
# INTT is bottom stock
# INUV is bottom stock
# INVE is bottom stock
# INVO is bottom stock
# INZY is top stock
# IOBT is bottom stock
# IONM is top stock
# IONQ is bottom stock
# IOVA is top stock
# IPA is top stock
# IPAR is top stock
# IPSC is top stock
# IPW is top stock
# IPWR is bottom stock
# IR is top stock
# IRBT is bottom stock
# IRDM is bottom stock
# IREN is bottom stock
# IRIX is bottom stock
# IRON is top stock
# IRWD is top stock
# ISDR is bottom stock
# ISPC is bottom stock
# ISPR is bottom stock
# ISUN is bottom stock
# ITCI is top stock
# ITP is bottom stock
# ITRG is bottom stock
# ITRM is bottom stock
# ITT is top stock
# IZM is bottom stock
# J is top stock
# JAGX is bottom stock
# JAKK is bottom stock
# JAN is top stock
# JANX is bottom stock
# JBHT is top stock
# JBI is top stock
# JBL is top stock
# JBLU is top stock
# JBSS is top stock
# JBT is top stock
# JELD is top stock
# JKHY is top stock
# JMSB is bottom stock
# JOAN is top stock
# JRVR is top stock
# JSDA is top stock
# JSPR is top stock
# JTAI is bottom stock
# JWN is top stock
# JXN is top stock
# JYNT is top stock
# KAI is top stock
# KALV is top stock
# KAVL is top stock
# KEX is top stock
# KEY is top stock
# KFRC is top stock
# KFS is top stock
# KFY is top stock
# KINS is top stock
# KIQ is top stock
# KITT is bottom stock
# KKR is top stock
# KLTR is bottom stock
# KLXE is bottom stock
# KMX is top stock
# KN is bottom stock
# KNDI is bottom stock
# KNSA is top stock
# KNTE is bottom stock
# KOD is top stock
# KOP is top stock
# KOPN is top stock
# KOS is bottom stock
# KOSS is bottom stock
# KPLT is top stock
# KPTI is top stock
# KRC is bottom stock
# KREF is bottom stock
# KRMD is bottom stock
# KRNY is bottom stock
# KRT is top stock
# KRUS is top stock
# KSCP is bottom stock
# KTB is top stock
# KTCC is top stock
# KTRA is bottom stock
# KTTA is bottom stock
# KUKE is top stock
# KURA is top stock
# KWE is bottom stock
# KYMR is top stock
# LAAC is bottom stock
# LANC is top stock
# LASR is top stock
# LAZ is top stock
# LBPH is bottom stock
# LCAA is bottom stock
# LCTX is bottom stock
# LCUT is top stock
# LDI is bottom stock
# LDOS is top stock
# LDTC is top stock
# LEDS is top stock
# LEG is bottom stock
# LEGH is top stock
# LESL is top stock
# LEU is bottom stock
# LEVI is top stock
# LEXX is top stock
# LFCR is top stock
# LFLY is bottom stock
# LFT is bottom stock
# LFVN is top stock
# LFWD is bottom stock
# LGMK is bottom stock
# LGO is bottom stock
# LGVN is bottom stock
# LICY is bottom stock
# LIFE is top stock
# LIFW is bottom stock
# LINC is top stock
# LIND is bottom stock
# LINK is bottom stock
# LIQT is bottom stock
# LIXT is top stock
# LKFN is top stock
# LL is bottom stock
# LMAT is top stock
# LMFA is bottom stock
# LNKB is bottom stock
# LNTH is bottom stock
# LNW is top stock
# LNZA is bottom stock
# LOB is bottom stock
# LOCL is top stock
# LOCO is top stock
# LODE is bottom stock
# LOOP is bottom stock
# LPG is bottom stock
# LPLA is top stock
# LPRO is top stock
# LPSN is bottom stock
# LPTH is top stock
# LPTV is bottom stock
# LPTX is bottom stock
# LQDA is top stock
# LRMR is top stock
# LSCC is top stock
# LSF is bottom stock
# LSPD is bottom stock
# LSTA is bottom stock
# LTBR is bottom stock
# LTRPA is top stock
# LTRX is bottom stock
# LTRY is bottom stock
# LUCD is bottom stock
# LUNA is top stock
# LUNG is top stock
# LUNR is top stock
# LUV is top stock
# LUXH is bottom stock
# LVO is top stock
# LWAY is bottom stock
# LWLG is top stock
# LXFR is bottom stock
# LXRX is top stock
# LXU is bottom stock
# LYT is bottom stock
# LZB is top stock
# LZM is bottom stock
# MA is top stock
# MAC is top stock
# MACK is top stock
# MAIA is top stock
# MAMA is bottom stock
# MANH is top stock
# MARA is top stock
# MASI is top stock
# MASS is bottom stock
# MATW is bottom stock
# MAX is top stock
# MAXN is bottom stock
# MBCN is bottom stock
# MBIO is top stock
# MBLY is bottom stock
# MBOT is bottom stock
# MBRX is bottom stock
# MCAF is top stock
# MCB is bottom stock
# MCBS is top stock
# MCRB is bottom stock
# MCY is top stock
# MDB is top stock
# MDIA is bottom stock
# MDNAF is top stock
# MDV is bottom stock
# MEC is bottom stock
# MED is bottom stock
# MEDP is top stock
# MEDS is bottom stock
# MEG is top stock
# MEIP is bottom stock
# MERC is bottom stock
# METC is bottom stock
# MGAM is bottom stock
# MGEE is bottom stock
# MGIH is top stock
# MGNI is top stock
# MGNX is top stock
# MGOL is bottom stock
# MGRC is top stock
# MICS is bottom stock
# MIGI is bottom stock
# MIMO is top stock
# MINM is top stock
# MITQ is bottom stock
# MKL is top stock
# MKSI is top stock
# MKTW is bottom stock
# MKTX is bottom stock
# ML is bottom stock
# MLAB is bottom stock
# MLEC is bottom stock
# MLGO is bottom stock
# MLI is top stock
# MLKN is top stock
# MLM is top stock
# MLR is top stock
# MLTX is top stock
# MLYS is top stock
# MMAT is top stock
# MMLP is bottom stock
# MMM is bottom stock
# MMYT is top stock
# MNMD is top stock
# MNOV is bottom stock
# MNPR is bottom stock
# MNRO is top stock
# MNSB is bottom stock
# MNTK is bottom stock
# MNTS is bottom stock
# MNTX is bottom stock
# MNY is top stock
# MOBX is bottom stock
# MOD is top stock
# MODD is bottom stock
# MODV is top stock
# MORF is top stock
# MORN is top stock
# MOS is bottom stock
# MOTS is bottom stock
# MOVE is bottom stock
# MPTI is top stock
# MPU is top stock
# MPWR is top stock
# MPX is top stock
# MRAI is bottom stock
# MRAM is top stock
# MRBK is bottom stock
# MRDB is top stock
# MRK is top stock
# MRKR is bottom stock
# MRNA is bottom stock
# MRNS is bottom stock
# MRSN is top stock
# MRT is top stock
# MRUS is top stock
# MRVI is bottom stock
# MSA is top stock
# MSAI is bottom stock
# MSCI is top stock
# MSGE is top stock
# MSGM is bottom stock
# MSS is top stock
# MSTR is top stock
# MTA is bottom stock
# MTBL is bottom stock
# MTN is top stock
# MTNB is bottom stock
# MTRX is top stock
# MTW is top stock
# MTX is top stock
# MUSA is top stock
# MUX is top stock
# MVLA is bottom stock
# MVST is bottom stock
# MWA is top stock
# MYGN is top stock
# MYMD is bottom stock
# MYO is bottom stock
# MYRG is top stock
# MYSZ is bottom stock
# NAK is bottom stock
# NAOV is top stock
# NATH is bottom stock
# NAVB is bottom stock
# NB is top stock
# NBTB is bottom stock
# NBY is bottom stock
# NCNC is top stock
# NCPL is bottom stock
# NDRA is bottom stock
# NEM is bottom stock
# NEOG is bottom stock
# NEON is bottom stock
# NEPT is bottom stock
# NERV is top stock
# NET is top stock
# NEWP is bottom stock
# NEXI is top stock
# NEXT is top stock
# NFG is bottom stock
# NG is bottom stock
# NGD is bottom stock
# NGM is top stock
# NICK is top stock
# NINE is bottom stock
# NKGN is bottom stock
# NKLA is bottom stock
# NKTR is top stock
# NKTX is top stock
# NLST is bottom stock
# NMG is bottom stock
# NMRD is bottom stock
# NMRK is top stock
# NMTC is bottom stock
# NN is bottom stock
# NNBR is top stock
# NNI is top stock
# NODK is top stock
# NOG is bottom stock
# NOTE is top stock
# NOTV is top stock
# NOV is bottom stock
# NOVA is bottom stock
# NPCE is top stock
# NPO is top stock
# NPWR is bottom stock
# NRBO is top stock
# NRC is top stock
# NRDY is top stock
# NREF is bottom stock
# NRGV is bottom stock
# NRIX is bottom stock
# NS is top stock
# NSC is top stock
# NSIT is top stock
# NSP is bottom stock
# NSPR is top stock
# NSSC is top stock
# NSTG is bottom stock
# NSYS is top stock
# NTAP is top stock
# NTBL is top stock
# NTRB is top stock
# NTWK is top stock
# NUE is top stock
# NUKK is bottom stock
# NUVB is top stock
# NUVL is top stock
# NUWE is bottom stock
# NUZE is bottom stock
# NVAX is bottom stock
# NVCR is top stock
# NVCT is bottom stock
# NVDA is top stock
# NVEC is top stock
# NVEE is top stock
# NVEI is top stock
# NVFY is bottom stock
# NVRO is bottom stock
# NVST is bottom stock
# NVTS is bottom stock
# NVVE is top stock
# NWFL is bottom stock
# NWL is bottom stock
# NWPX is top stock
# NX is top stock
# NXE is top stock
# NXGL is bottom stock
# NXL is bottom stock
# NXPI is top stock
# NXPL is bottom stock
# NXT is top stock
# NXTC is top stock
# NXU is bottom stock
# NYCB is bottom stock
# O is bottom stock
# OABI is bottom stock
# OB is top stock
# OBIO is bottom stock
# OBT is bottom stock
# OCC is bottom stock
# OCN is bottom stock
# OCUL is top stock
# OCUP is bottom stock
# OCX is bottom stock
# ODC is top stock
# ODFL is top stock
# ODV is bottom stock
# OESX is top stock
# OFS is bottom stock
# OGEN is bottom stock
# OGI is top stock
# OKYO is bottom stock
# OLB is bottom stock
# OLMA is top stock
# OLO is top stock
# OLP is bottom stock
# OM is bottom stock
# OMCL is bottom stock
# OMEX is bottom stock
# OMI is top stock
# OMQS is bottom stock
# ON is top stock
# ONCT is top stock
# ONDS is bottom stock
# ONEW is bottom stock
# ONL is bottom stock
# ONMD is top stock
# ONTF is top stock
# ONTO is top stock
# OPEN is bottom stock
# OPFI is bottom stock
# OPI is bottom stock
# OPRT is bottom stock
# OPTN is top stock
# OR is top stock
# ORIC is top stock
# ORMP is top stock
# ORN is top stock
# OSA is bottom stock
# OSBC is bottom stock
# OSCR is top stock
# OSG is top stock
# OSIS is top stock
# OSPN is top stock
# OSW is top stock
# OTRK is bottom stock
# OTTR is top stock
# OUST is bottom stock
# OVID is top stock
# OWL is top stock
# OWLT is bottom stock
# OXM is top stock
# PACB is bottom stock
# PACK is bottom stock
# PAHC is top stock
# PALT is top stock
# PAPL is bottom stock
# PARAA is top stock
# PARR is top stock
# PATH is top stock
# PATK is top stock
# PAVM is bottom stock
# PAY is bottom stock
# PAYS is top stock
# PAYX is top stock
# PBF is top stock
# PBH is top stock
# PBLA is top stock
# PBYI is top stock
# PCB is bottom stock
# PCOR is top stock
# PCRX is bottom stock
# PCSA is top stock
# PCT is top stock
# PCVX is top stock
# PDEX is bottom stock
# PDFS is top stock
# PDM is bottom stock
# PEB is top stock
# PEBK is bottom stock
# PED is bottom stock
# PEGA is top stock
# PEGY is bottom stock
# PENN is bottom stock
# PEPG is top stock
# PESI is bottom stock
# PET is top stock
# PETS is bottom stock
# PFIE is bottom stock
# PFLT is bottom stock
# PFSI is top stock
# PG is top stock
# PGR is top stock
# PGTI is bottom stock
# PH is top stock
# PHAT is bottom stock
# PHIO is bottom stock
# PHR is top stock
# PHX is bottom stock
# PI is top stock
# PIII is bottom stock
# PIPR is top stock
# PIXY is bottom stock
# PJT is top stock
# PKBK is bottom stock
# PLAB is top stock
# PLAY is top stock
# PLCE is bottom stock
# PLG is bottom stock
# PLL is bottom stock
# PLMR is top stock
# PLUR is top stock
# PLUS is top stock
# PMD is bottom stock
# PMVP is bottom stock
# PNR is top stock
# PNRG is bottom stock
# POET is top stock
# POL is bottom stock
# POST is top stock
# POWL is top stock
# POWW is top stock
# PRFT is top stock
# PRG is top stock
# PRIM is top stock
# PRLD is bottom stock
# PRM is top stock
# PRME is bottom stock
# PROC is bottom stock
# PROF is top stock
# PROK is bottom stock
# PRPL is top stock
# PRSO is bottom stock
# PRST is bottom stock
# PRTA is bottom stock
# PRTG is bottom stock
# PRTS is bottom stock
# PSHG is bottom stock
# PSNL is bottom stock
# PSTV is top stock
# PSTX is top stock
# PTCT is bottom stock
# PTGX is top stock
# PTON is bottom stock
# PTRAQ is bottom stock
# PULM is bottom stock
# PVH is top stock
# PWP is top stock
# PXLW is top stock
# PXMD is bottom stock
# PYPL is top stock
# PYXS is top stock
# PZG is bottom stock
# QBTS is top stock
# QLGN is bottom stock
# QLYS is bottom stock
# QMCO is top stock
# QNCX is bottom stock
# QNRX is bottom stock
# QNST is top stock
# QRVO is top stock
# QS is bottom stock
# QSG is top stock
# QTRX is bottom stock
# QTWO is top stock
# QUAD is top stock
# QUBT is top stock
# QURE is bottom stock
# R is top stock
# RADCQ is bottom stock
# RAIL is top stock
# RAPT is top stock
# RARE is bottom stock
# RAVE is bottom stock
# RBCAA is top stock
# RBT is bottom stock
# RCAT is bottom stock
# RCEL is top stock
# RCKY is top stock
# RCM is top stock
# RCUS is bottom stock
# RDFN is bottom stock
# RDI is bottom stock
# RDNT is top stock
# RDVT is bottom stock
# RDW is top stock
# RDZN is top stock
# REBN is top stock
# REFR is bottom stock
# REKR is bottom stock
# RELI is bottom stock
# RELL is bottom stock
# RENT is top stock
# REPL is bottom stock
# REX is bottom stock
# REXR is bottom stock
# RGEN is top stock
# RGLS is top stock
# RGNX is top stock
# RGTI is top stock
# RIBT is bottom stock
# RIDEQ is top stock
# RIG is bottom stock
# RIGL is bottom stock
# RIOT is bottom stock
# RIVN is top stock
# RJF is top stock
# RKDA is bottom stock
# RL is top stock
# RLAY is bottom stock
# RLI is top stock
# RLMD is top stock
# RLYB is bottom stock
# RM is bottom stock
# RMBL is bottom stock
# RMBS is bottom stock
# RMCF is bottom stock
# RMCO is bottom stock
# RMR is bottom stock
# RMTI is bottom stock
# RNA is top stock
# RNAC is top stock
# RNAZ is top stock
# RNLX is top stock
# RNR is top stock
# RNW is bottom stock
# ROAD is top stock
# ROCK is top stock
# ROI is bottom stock
# ROK is bottom stock
# ROOT is bottom stock
# ROST is top stock
# ROVR is top stock
# RPD is top stock
# RPTX is top stock
# RRC is bottom stock
# RRR is top stock
# RRX is top stock
# RS is top stock
# RSG is top stock
# RSI is top stock
# RSLS is bottom stock
# RUM is top stock
# RVLV is top stock
# RVMD is top stock
# RVNC is bottom stock
# RVSB is bottom stock
# RXO is bottom stock
# RXRX is bottom stock
# RYAM is top stock
# RYTM is top stock
# RZLT is top stock
# S is top stock
# SACH is bottom stock
# SAFT is top stock
# SAGE is top stock
# SAH is top stock
# SAIA is top stock
# SANA is bottom stock
# SANM is top stock
# SAR is bottom stock
# SAVA is top stock
# SAVE is bottom stock
# SBET is bottom stock
# SBFM is bottom stock
# SBGI is top stock
# SBH is top stock
# SBIG is top stock
# SBR is bottom stock
# SCHL is top stock
# SCKT is bottom stock
# SCLX is bottom stock
# SCM is bottom stock
# SCPH is bottom stock
# SCPX is bottom stock
# SCTL is top stock
# SCX is top stock
# SCYX is bottom stock
# SDA is bottom stock
# SDCCQ is top stock
# SDIG is bottom stock
# SDOT is bottom stock
# SEB is bottom stock
# SEEL is bottom stock
# SEER is bottom stock
# SELF is bottom stock
# SENEA is bottom stock
# SENS is top stock
# SERA is top stock
# SES is bottom stock
# SEVN is bottom stock
# SEZL is top stock
# SF is top stock
# SFES is bottom stock
# SFIX is top stock
# SFST is bottom stock
# SFTGQ is bottom stock
# SG is top stock
# SGA is top stock
# SGBX is bottom stock
# SGH is top stock
# SGHT is bottom stock
# SGLY is top stock
# SGML is bottom stock
# SGMO is top stock
# SGRP is top stock
# SGRY is top stock
# SHAK is top stock
# SHLS is top stock
# SHOT is bottom stock
# SHPH is bottom stock
# SIDU is bottom stock
# SIF is bottom stock
# SIG is top stock
# SIGA is bottom stock
# SILK is top stock
# SING is bottom stock
# SINT is bottom stock
# SIRI is bottom stock
# SISI is top stock
# SITM is top stock
# SJ is bottom stock
# SKLZ is top stock
# SKWD is bottom stock
# SKY is top stock
# SKYT is top stock
# SKYW is top stock
# SLAB is top stock
# SLDP is top stock
# SLE is top stock
# SLI is bottom stock
# SLND is bottom stock
# SLNH is bottom stock
# SLQT is top stock
# SLRX is bottom stock
# SLS is bottom stock
# SMCI is top stock
# SMFL is bottom stock
# SMID is top stock
# SMMT is top stock
# SMP is top stock
# SMPL is bottom stock
# SMR is top stock
# SMSI is bottom stock
# SMTSF is top stock
# SMWB is top stock
# SNAL is bottom stock
# SNAP is bottom stock
# SNAX is bottom stock
# SNBR is bottom stock
# SND is bottom stock
# SNDL is bottom stock
# SNES is bottom stock
# SNFCA is bottom stock
# SNGX is bottom stock
# SNPX is bottom stock
# SNSE is bottom stock
# SNTI is bottom stock
# SOAR is bottom stock
# SOBR is top stock
# SOHO is bottom stock
# SOLO is bottom stock
# SOND is bottom stock
# SONM is bottom stock
# SONX is bottom stock
# SOUN is top stock
# SPB is top stock
# SPCE is bottom stock
# SPEC is top stock
# SPFI is bottom stock
# SPH is top stock
# SPHR is top stock
# SPI is bottom stock
# SPIR is top stock
# SPLK is top stock
# SPNT is top stock
# SPOK is top stock
# SPRB is top stock
# SPRY is top stock
# SPSC is top stock
# SPT is top stock
# SPWH is bottom stock
# SPXC is top stock
# SQFT is bottom stock
# SQZB is top stock
# SRI is top stock
# SRNEQ is bottom stock
# SRTS is top stock
# SSD is top stock
# SSSS is bottom stock
# STAF is bottom stock
# STEM is bottom stock
# STEP is top stock
# STI is bottom stock
# STIM is top stock
# STIX is bottom stock
# STKS is bottom stock
# STLD is top stock
# STNG is top stock
# STRA is top stock
# STRC is bottom stock
# STRM is top stock
# STRO is top stock
# STRS is bottom stock
# STRT is top stock
# STSS is bottom stock
# STXS is top stock
# SUNW is bottom stock
# SURG is top stock
# SVFD is bottom stock
# SVII is top stock
# SVMH is bottom stock
# SVRA is top stock
# SWAG is bottom stock
# SWI is top stock
# SWIM is top stock
# SWTX is top stock
# SXI is top stock
# SXTC is bottom stock
# SYBX is bottom stock
# SYK is top stock
# SYTA is bottom stock
# SYY is top stock
# TAC is bottom stock
# TAIT is bottom stock
# TAL is top stock
# TARA is top stock
# TARS is top stock
# TBBK is top stock
# TBIO is bottom stock
# TBLA is top stock
# TBLT is bottom stock
# TBNK is bottom stock
# TBPH is bottom stock
# TCMD is top stock
# TCON is top stock
# TCPC is bottom stock
# TCRT is top stock
# TCRX is bottom stock
# TCS is bottom stock
# TDG is top stock
# TELL is bottom stock
# TEVA is top stock
# TFFP is top stock
# TFIN is top stock
# TGI is top stock
# TGL is bottom stock
# TGTX is bottom stock
# THAR is bottom stock
# THC is top stock
# THG is top stock
# THM is bottom stock
# THMO is top stock
# THRD is bottom stock
# THRX is top stock
# THRY is top stock
# THS is top stock
# TILE is top stock
# TIPT is bottom stock
# TIVC is bottom stock
# TK is top stock
# TKLF is bottom stock
# TKNO is bottom stock
# TKO is top stock
# TKR is top stock
# TLPH is top stock
# TLS is top stock
# TMC is bottom stock
# TMCI is top stock
# TMDIF is bottom stock
# TMHC is top stock
# TNC is top stock
# TNDM is bottom stock
# TNET is bottom stock
# TNK is top stock
# TNL is top stock
# TNON is bottom stock
# TNYA is top stock
# TOL is top stock
# TOMZ is bottom stock
# TOON is bottom stock
# TOP is bottom stock
# TOVX is top stock
# TPCS is bottom stock
# TPG is top stock
# TPHS is top stock
# TPIC is bottom stock
# TPL is bottom stock
# TPR is top stock
# TR is bottom stock
# TRAK is top stock
# TRDA is top stock
# TREE is top stock
# TREX is top stock
# TRIP is top stock
# TRKAQ is top stock
# TRMB is top stock
# TRML is top stock
# TRNO is top stock
# TRNS is top stock
# TRUE is top stock
# TRUP is top stock
# TRVI is top stock
# TRVN is bottom stock
# TSE is bottom stock
# TSHA is bottom stock
# TSLA is bottom stock
# TSQ is top stock
# TSVT is top stock
# TT is top stock
# TTC is top stock
# TTEK is top stock
# TTMI is top stock
# TTNP is bottom stock
# TUSK is bottom stock
# TW is top stock
# TWO is bottom stock
# TWOU is bottom stock
# TWST is top stock
# TXG is bottom stock
# TXRH is top stock
# TXT is top stock
# TYRA is top stock
# TZOO is bottom stock
# U is bottom stock
# UAMY is bottom stock
# UAN is top stock
# UAVS is top stock
# UBER is top stock
# UBX is bottom stock
# UCTT is top stock
# UEC is top stock
# UEIC is bottom stock
# UFCS is top stock
# UFI is bottom stock
# UFPT is top stock
# UGRO is top stock
# UHAL is bottom stock
# UHG is bottom stock
# UHS is top stock
# UIS is top stock
# ULBI is top stock
# ULCC is top stock
# ULH is top stock
# ULTA is top stock
# UNB is bottom stock
# UNCY is top stock
# UNFI is top stock
# UNIT is bottom stock
# UNM is top stock
# UONE is bottom stock
# UPLD is top stock
# URGN is top stock
# URI is top stock
# UROY is top stock
# USAS is top stock
# USAU is bottom stock
# USCB is bottom stock
# USEG is bottom stock
# USLM is top stock
# USO is top stock
# UTHR is bottom stock
# UTI is top stock
# UTMD is bottom stock
# UTZ is top stock
# UUU is bottom stock
# UUUU is top stock
# UVV is bottom stock
# VABK is bottom stock
# VAC is top stock
# VAPO is bottom stock
# VATE is bottom stock
# VAXX is bottom stock
# VBIV is top stock
# VCEL is top stock
# VCSA is top stock
# VCTR is top stock
# VERA is top stock
# VERI is top stock
# VERU is bottom stock
# VERV is bottom stock
# VERX is bottom stock
# VEV is bottom stock
# VFF is bottom stock
# VFS is bottom stock
# VGAS is top stock
# VGR is top stock
# VHC is top stock
# VICR is top stock
# VIEW is bottom stock
# VINC is top stock
# VINE is bottom stock
# VINO is bottom stock
# VIRI is bottom stock
# VIRT is bottom stock
# VIRX is top stock
# VIVK is bottom stock
# VKTX is top stock
# VLCN is top stock
# VLD is bottom stock
# VMAR is bottom stock
# VMC is top stock
# VMD is top stock
# VMEO is top stock
# VNCE is bottom stock
# VNDA is top stock
# VNOM is top stock
# VNRX is bottom stock
# VOR is top stock
# VOXX is bottom stock
# VRAR is top stock
# VRAX is bottom stock
# VRCA is bottom stock
# VREX is bottom stock
# VRM is bottom stock
# VRME is top stock
# VRNS is top stock
# VRNT is top stock
# VRT is top stock
# VS is bottom stock
# VSAT is bottom stock
# VSCO is top stock
# VSEC is top stock
# VSTE is bottom stock
# VSTM is top stock
# VTNR is bottom stock
# VTSI is top stock
# VTYX is bottom stock
# VUZI is bottom stock
# VVOS is bottom stock
# VVPR is bottom stock
# VVV is top stock
# VXRT is top stock
# VYGR is bottom stock
# VYNE is bottom stock
# VZLA is top stock
# W is bottom stock
# WAB is top stock
# WABC is bottom stock
# WAFU is bottom stock
# WATT is top stock
# WAVD is top stock
# WCC is top stock
# WCN is top stock
# WEAV is top stock
# WETG is top stock
# WEX is top stock
# WFG is bottom stock
# WHLR is bottom stock
# WHR is bottom stock
# WINA is bottom stock
# WINT is bottom stock
# WIRE is top stock
# WISA is bottom stock
# WKC is top stock
# WKHS is bottom stock
# WLFC is top stock
# WLKP is bottom stock
# WLY is top stock
# WMG is top stock
# WMS is top stock
# WMT is top stock
# WNC is top stock
# WNEB is bottom stock
# WNNR is top stock
# WOLF is bottom stock
# WOOF is bottom stock
# WOR is top stock
# WORX is bottom stock
# WPC is bottom stock
# WPRT is bottom stock
# WRAP is top stock
# WRK is top stock
# WRLD is top stock
# WRN is bottom stock
# WSC is top stock
# WSM is top stock
# WSR is top stock
# WST is top stock
# WTS is top stock
# WTW is top stock
# WVE is bottom stock
# WW is bottom stock
# WWW is top stock
# WYNN is top stock
# XAIR is top stock
# XBIT is top stock
# XBP is bottom stock
# XELA is bottom stock
# XELB is bottom stock
# XENE is top stock
# XMTR is top stock
# XNCR is bottom stock
# XPEL is top stock
# XPL is bottom stock
# XPO is top stock
# XPON is bottom stock
# XPRO is top stock
# XRX is top stock
# XTNT is bottom stock
# XXII is bottom stock
# XYL is top stock
# YCBD is top stock
# YEXT is top stock
# YMAB is top stock
# YOSH is bottom stock
# YS is bottom stock
# YTEN is bottom stock
# YTRA is bottom stock
# ZD is top stock
# ZDGE is top stock
# ZEUS is top stock
# ZEVY is bottom stock
# ZFOX is top stock
# ZIMV is top stock
# ZIVO is top stock
# ZLAB is bottom stock
# ZNOG is bottom stock
# ZNTL is bottom stock
# ZOM is bottom stock
# ZS is top stock
# ZVIA is bottom stock
# ZVSA is bottom stock
# ZWS is top stock
# ZYXI is top stock

# %%
gc.collect()
